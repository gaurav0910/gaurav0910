# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav0910/gaurav0910/blob/main/Webscrapping%20of%20ISL%20standings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests

# %%
scrape_url = "https://api.sofascore.com/api/v1/unique-tournament/1900/season/34713/standings/total"
r = requests.get(scrape_url)
json_object = json.loads(r.content)

# %%
urlopen(scrape_url)

# %%
type(json_object)
# Out:
# dict

# %%
json_object.keys()
# Out:
# dict_keys(['standings'])

# %%
json_object["standings"][0]["rows"]
# Out:
# [{'descriptions': [],
#   'draws': 4,
#   'id': 541930,
#   'losses': 4,
#   'matches': 20,
#   'points': 40,
#   'position': 1,
#   'promotion': {'id': 6, 'text': 'Playoffs'},
#   'scoresAgainst': 18,
#   'scoresFor': 35,
#   'team': {'gender': 'M',
#    'id': 174600,
#    'name': 'Mumbai City FC',
#    'nameCode': 'MCI',
#    'national': False,
#    'shortName': 'Mumbai City',
#    'slug': 'mumbai-city-fc',
#    'teamColors': {'primary': '#0000ff',
#     'secondary': '#0000ff',
#     'text': '#0000ff'},
#    'type': 0,
#    'userCount': 7318},
#   'wins': 12},
#  {'descriptions': [],
#   'draws': 4,
#   'id': 544103,
#   'losses': 4,
#   'matches': 20,
#   'points': 40,
#   'position': 2,
#   'promotion': {'id': 6, 'text': 'Playoffs'},
#   'scoresAgainst': 15,
#   'scoresFor': 28,
#   'team': {'gender': 'M',
#    'id': 370834,
#    'name': 'ATK Mohun Bagan FC',
#    'nameCode': 'AMB',
#    'national': False,
#    'shortName': 'ATK Mohun Bagan',
#    'slug': 'atk-mohun-bagan-fc',
#    'teamColors': {'primary': '#91191b',
#     'secondary': '#246a1d',
#     'text': '#246a1d'},
#    'type': 0,
#    'userCount': 6888},
#   'wins': 12},
#  {'descriptions': [],
#   'draws': 9,
#   'id': 541931,
#   'losses': 3,
#   'matches': 20,
#   'points': 33,
#   'position': 3,
#   'promotion': {'id': 6, 'text': 'Playoffs'},
#   'scoresAgainst': 25,
#   'scoresFor': 31,
#   'team': {'gender': 'M',
#    'id': 174602,
#    'name': 'Northeast United',
#    'nameCode': 'NUN',
#    'national': False,
#    'shortName': 'Northeast Utd',
#    'slug': 'northeast-united',
#    'teamColors': {'primary': '#ffffff',
#     'secondary': '#ffffff',
#     'text': '#ffffff'},
#    'type': 0,
#    'userCount': 3926},
#   'wins': 8},
#  {'descriptions': [],
#   'draws': 10,
#   'id': 541925,
#   'losses': 3,
#   'matches': 20,
#   'points': 31,
#   'position': 4,
#   'promotion': {'id': 6, 'text': 'Playoffs'},
#   'scoresAgainst': 23,
#   'scoresFor': 31,
#   'team': {'gender': 'M',
#    'id': 174594,
#    'name': 'FC Goa',
#    'nameCode': 'GOA',
#    'national': False,
#    'shortName': 'Goa',
#    'slug': 'fc-goa',
#    'teamColors': {'primary': '#0033ff',
#     'secondary': '#0033ff',
#     'text': '#0033ff'},
#    'type': 0,
#    'userCount': 7722},
#   'wins': 7},
#  {'descriptions': [],
#   'draws': 11,
#   'id': 541926,
#   'losses': 3,
#   'matches': 20,
#   'points': 29,
#   'position': 5,
#   'scoresAgainst': 19,
#   'scoresFor': 27,
#   'team': {'disabled': False,
#    'gender': 'M',
#    'id': 331840,
#    'name': 'Hyderabad FC',
#    'nameCode': 'HYD',
#    'national': False,
#    'shortName': 'Hyderabad',
#    'slug': 'hyderabad-fc',
#    'teamColors': {'primary': '#0f141b',
#     'secondary': '#f8ca1c',
#     'text': '#f8ca1c'},
#    'type': 0,
#    'userCount': 2842},
#   'wins': 6},
#  {'descriptions': [],
#   'draws': 6,
#   'id': 541927,
#   'losses': 7,
#   'matches': 20,
#   'points': 27,
#   'position': 6,
#   'scoresAgainst': 22,
#   'scoresFor': 21,
#   'team': {'gender': 'M',
#    'id': 267915,
#    'name': 'Jamshedpur',
#    'nameCode': 'JAM',
#    'national': False,
#    'shortName': 'Jamshedpur',
#    'slug': 'jamshedpur',
#    'teamColors': {'primary': '#eb2325',
#     'secondary': '#000000',
#     'text': '#000000'},
#    'type': 0,
#    'userCount': 2798},
#   'wins': 7},
#  {'descriptions': [],
#   'draws': 7,
#   'id': 541923,
#   'losses': 8,
#   'matches': 20,
#   'points': 22,
#   'position': 7,
#   'scoresAgainst': 28,
#   'scoresFor': 26,
#   'team': {'gender': 'M',
#    'id': 118670,
#    'name': 'Bengaluru FC',
#    'nameCode': 'BEN',
#    'national': False,
#    'shortName': 'Bengaluru',
#    'slug': 'bengaluru-fc',
#    'teamColors': {'primary': '#0b062c',
#     'secondary': '#000000',
#     'text': '#000000'},
#    'type': 0,
#    'userCount': 6924},
#   'wins': 5},
#  {'descriptions': [],
#   'draws': 11,
#   'id': 541924,
#   'losses': 6,
#   'matches': 20,
#   'points': 20,
#   'position': 8,
#   'scoresAgainst': 23,
#   'scoresFor': 17,
#   'team': {'gender': 'M',
#    'id': 174590,
#    'name': 'Chennaiyin FC',
#    'nameCode': 'CHE',
#    'national': False,
#    'shortName': 'Chennaiyin',
#    'slug': 'chennaiyin-fc',
#    'teamColors': {'primary': '#0000ff',
#     'secondary': '#0000ff',
#     'text': '#0000ff'},
#    'type': 0,
#    'userCount': 4352},
#   'wins': 3},
#  {'descriptions': [],
#   'draws': 8,
#   'id': 541933,
#   'losses': 9,
#   'matches': 20,
#   'points': 17,
#   'position': 9,
#   'scoresAgainst': 33,
#   'scoresFor': 22,
#   'team': {'disabled': False,
#    'gender': 'M',
#    'id': 40655,
#    'name': 'SC East Bengal',
#    'nameCode': 'EBC',
#    'national': False,
#    'shortName': 'SC East Bengal',
#    'slug': 'sc-east-bengal',
#    'teamColors': {'primary': '#ed1c24',
#     'secondary': '#ffc90e',
#     'text': '#ffc90e'},
#    'type': 0,
#    'userCount': 3751},
#   'wins': 3},
#  {'descriptions': [],
#   'draws': 8,
#   'id': 541928,
#   'losses': 9,
#   'matches': 20,
#   'points': 17,
#   'position': 10,
#   'scoresAgainst': 36,
#   'scoresFor': 23,
#   'team': {'disabled': False,
#    'gender': 'M',
#    'id': 174598,
#    'name': 'Kerala Blasters',
#    'nameCode': 'KBL',
#    'national': False,
#    'shortName': 'Blasters',
#    'slug': 'kerala-blasters',
#    'teamColors': {'primary': '#ffff00',
#     'secondary': '#ffff00',
#     'text': '#ffff00'},
#    'type': 0,
#    'userCount': 10307},
#   'wins': 3},
#  {'descriptions': [],
#   'draws': 6,
#   'id': 541932,
#   'losses': 12,
#   'matches': 20,
#   'points': 12,
#   'position': 11,
#   'scoresAgainst': 44,
#   'scoresFor': 25,
#   'team': {'gender': 'M',
#    'id': 174592,
#    'name': 'Odisha Football Club',
#    'nameCode': 'DDY',
#    'national': False,
#    'shortName': 'Odisha FC',
#    'slug': 'odisha-football-club',
#    'teamColors': {'primary': '#ff6600',
#     'secondary': '#ff6600',
#     'text': '#ff6600'},
#    'type': 0,
#    'userCount': 2804},
#   'wins': 2}]

# %%
pd.json_normalize(json_object["standings"][0]["rows"])
# Out:
#    descriptions  position  matches  ...  promotion.text  promotion.id  team.disabled
# 0            []         1       20  ...        Playoffs           6.0            NaN
# 1            []         2       20  ...        Playoffs           6.0            NaN
# 2            []         3       20  ...        Playoffs           6.0            NaN
# 3            []         4       20  ...        Playoffs           6.0            NaN
# 4            []         5       20  ...             NaN           NaN          False
# 5            []         6       20  ...             NaN           NaN            NaN
# 6            []         7       20  ...             NaN           NaN            NaN
# 7            []         8       20  ...             NaN           NaN            NaN
# 8            []         9       20  ...             NaN           NaN          False
# 9            []        10       20  ...             NaN           NaN          False
# 10           []        11       20  ...             NaN           NaN            NaN
#
# [11 rows x 25 columns]

# %%
isl_standings_df = pd.json_normalize(json_object["standings"][0]["rows"])

# %%
from google.colab import files
isl_standings_df.to_csv('isl_data.csv')
files.download('isl_data.csv')
